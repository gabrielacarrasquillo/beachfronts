# %% [markdown]
# # Project 2: A look into solar farms across the island

# %% [markdown]
# This code is the data analysis conducted as part of Project 2 for Lede Program, and it's a look into construction permits given to establish solar farms across the archipélago.

# %%
import pandas as pd
import numpy as np

# %%
df_main = pd.read_excel("Main_Permisos Aprobados OGPE_2012_2021.xlsm")

# %%
df_update = pd.read_excel("Update_Permisos Aprobados OGPE_2012_2021.xlsx")

# %%
df_main.shape
# Out:
# (371852, 12)

# %%
df_update.shape
# Out:
# (1365, 12)

# %%
print(371852 + 1365)
# Out:
# 373217

# %% [markdown]
# The merge was sucessful since the sum of rows from both dataframes is equal to the merged df:

# %%
df = pd.concat([df_update, df_main])
df
# Out:
#         CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 0       848363  2021-415824-PCOC-021390  PERMIT_APPROVED         PCOC
# 1       848485  2021-416058-PCOC-021395  PERMIT_APPROVED         PCOC
# 2       848527  2021-416081-PCOC-021396  PERMIT_APPROVED         PCOC
# 3       848739  2021-415871-PCOC-021403  PERMIT_APPROVED         PCOC
# 4       849426  2021-415882-PCOC-021431  PERMIT_APPROVED         PCOC
# ...        ...                      ...              ...          ...
# 371847   20251   2014-016540-PUS-020251  PERMIT_APPROVED          PUS
# 371848   20252   2014-016542-CPI-020252  PERMIT_APPROVED          CPI
# 371849   20253   2014-016541-CSA-020253  PERMIT_APPROVED          CSA
# 371850   20254   2014-016543-PUS-020254  PERMIT_APPROVED          PUS
# 371851   20255   2014-016545-CPI-020255  PERMIT_APPROVED          CPI
#
#        FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 0          2021-12-23     2022-01-11
# 1          2021-12-23     2022-01-11
# ...

# %%
df.TIPO_TRÁMITE.value_counts().to_frame().head()
# Out:
#      TIPO_TRÁMITE
# DEC         84601
# PUS         47439
# CSA         42532
# CPI         39092
# PU          28694

# %%
df = df[df["TIPO_TRÁMITE"].isin(["PCOC","PCO"])]
df
# Out:
#         CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 0       848363  2021-415824-PCOC-021390  PERMIT_APPROVED         PCOC
# 1       848485  2021-416058-PCOC-021395  PERMIT_APPROVED         PCOC
# 2       848527  2021-416081-PCOC-021396  PERMIT_APPROVED         PCOC
# 3       848739  2021-415871-PCOC-021403  PERMIT_APPROVED         PCOC
# 4       849426  2021-415882-PCOC-021431  PERMIT_APPROVED         PCOC
# ...        ...                      ...              ...          ...
# 362580   50359   2015-039340-PCO-050359  PERMIT_APPROVED          PCO
# 362597   49277   2015-038699-PCO-049277  PERMIT_APPROVED          PCO
# 362600   49474   2015-038862-PCO-049474  PERMIT_APPROVED          PCO
# 369666   24696   2014-019562-PCO-024696  PERMIT_APPROVED          PCO
# 370516   24813   2014-019609-PCO-024813  PERMIT_APPROVED          PCO
#
#        FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 0          2021-12-23     2022-01-11
# 1          2021-12-23     2022-01-11
# ...

# %%
df.to_csv("permisos de construcción 2012-2021.csv",index=False)

# %% [markdown]
# # Part 2

# %%
df = pd.read_csv("permisos de construcción 2012-2021.csv")
df
# Out:
#        CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 0      848363  2021-415824-PCOC-021390  PERMIT_APPROVED         PCOC
# 1      848485  2021-416058-PCOC-021395  PERMIT_APPROVED         PCOC
# 2      848527  2021-416081-PCOC-021396  PERMIT_APPROVED         PCOC
# 3      848739  2021-415871-PCOC-021403  PERMIT_APPROVED         PCOC
# 4      849426  2021-415882-PCOC-021431  PERMIT_APPROVED         PCOC
# ...       ...                      ...              ...          ...
# 20112   50359   2015-039340-PCO-050359  PERMIT_APPROVED          PCO
# 20113   49277   2015-038699-PCO-049277  PERMIT_APPROVED          PCO
# 20114   49474   2015-038862-PCO-049474  PERMIT_APPROVED          PCO
# 20115   24696   2014-019562-PCO-024696  PERMIT_APPROVED          PCO
# 20116   24813   2014-019609-PCO-024813  PERMIT_APPROVED          PCO
#
#       FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 0         12/23/2021      1/11/2022
# 1         12/23/2021      1/11/2022
# ...

# %%
df.DESCRIPCIÓN_PROYECTO = df.DESCRIPCIÓN_PROYECTO.str.lower()
df.DESCRIPCIÓN_PROYECTO
# Out:
# 0        remodelacion interior para cuatro (4) apartame...
# 1                                              restaurante
# 2        permiso de construcción, privada - remodelació...
# 3              estructura comercial - angel l. lópez ramos
# 4        se solicita permiso de construcción certificad...
#                                ...
# 20112    permiso para una residencia plano modelo ferrm...
# 20113    residencia en hormigon y bloques unifamiliar d...
# 20114    residencia unifamiliar, dos plantas, en hormig...
# 20115                             kiosko y terraza abierta
# 20116                   construccion de vivienda (trailer)
# Name: DESCRIPCIÓN_PROYECTO, Length: 20117, dtype: object

# %%
df_hotel = df[df['DESCRIPCIÓN_PROYECTO'].str.contains('hotel')]
df_hotel
# Out:
#        CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 62     838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 284    822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 408    820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 495    805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 1447   774278  2020-298040-PCOC-016789  PERMIT_APPROVED         PCOC
# ...       ...                      ...              ...          ...
# 19206   91719   2015-050945-PCO-091719  PERMIT_APPROVED          PCO
# 19266   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 19621   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
# 19780   41504   2014-005393-PCO-041504  PERMIT_APPROVED          PCO
# 19862   41826   2014-005393-PCO-041826  PERMIT_APPROVED          PCO
#
#       FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 62         12/1/2021      12/6/2021
# 284       10/27/2021     11/17/2021
# ...

# %%
df_condohotel = df[df['DESCRIPCIÓN_PROYECTO'].str.contains('condohotel')]
df_condohotel
# Out:
#        CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 408    820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 3382   707843  2019-289961-PCOC-012341  PERMIT_APPROVED         PCOC
# 3645   698885  2021-351364-PCOC-011815  PERMIT_APPROVED         PCOC
# 6512   622355  2019-252750-PCOC-007373  PERMIT_APPROVED         PCOC
# 6902   598516  2018-248043-PCOC-005641  PERMIT_APPROVED         PCOC
# 10996  470036   2019-252750-PCO-017841  PERMIT_APPROVED          PCO
# 16176  248337   2016-135169-PCO-008633  PERMIT_APPROVED          PCO
# 16981  191656   2015-041888-PCO-191656  PERMIT_APPROVED          PCO
# 19266   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 19621   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
#
#       FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 408       10/21/2021      12/6/2021
# 3382        2/9/2021      4/19/2021
# 3645       1/18/2021      3/24/2021
# 6512        7/8/2020      7/13/2020
# ...

# %%
df_turÌstico = df[df['DESCRIPCIÓN_PROYECTO'].str.contains('turÌstico')]
df_turÌstico
# Out:
# Empty DataFrame
# Columns: [CPT_ID, TRÁMITE, ESTADO_TRÁMITE, TIPO_TRÁMITE, FECHA_SOMETIDO, FECHA_EXPEDIDO, NOMBRE_PROYECTO, DESCRIPCIÓN_PROYECTO, SOLICITANTE, MUNICIPIO, CDBG_DR, COORDENADAS_LAT, COORDENADAS_LON]
# Index: []

# %%
df_merge1 = df_hotel.merge(df_condohotel, how='outer')
df_merge1
# Out:
#     CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 0   838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 1   822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 2   820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 3   805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 4   774278  2020-298040-PCOC-016789  PERMIT_APPROVED         PCOC
# ..     ...                      ...              ...          ...
# 70   91719   2015-050945-PCO-091719  PERMIT_APPROVED          PCO
# 71   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 72   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
# 73   41504   2014-005393-PCO-041504  PERMIT_APPROVED          PCO
# 74   41826   2014-005393-PCO-041826  PERMIT_APPROVED          PCO
#
#    FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 0       12/1/2021      12/6/2021
# 1      10/27/2021     11/17/2021
# 2      10/21/2021      12/6/2021
# 3       10/7/2021     11/23/2021
# ...

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

df_merge2 = df_merge1.merge(df_turÌstico, how='outer')
df_merge2
# Out:
#     CPT_ID                  TRÁMITE   ESTADO_TRÁMITE TIPO_TRÁMITE  \
# 0   838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 1   822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 2   820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 3   805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 4   774278  2020-298040-PCOC-016789  PERMIT_APPROVED         PCOC
# ..     ...                      ...              ...          ...
# 70   91719   2015-050945-PCO-091719  PERMIT_APPROVED          PCO
# 71   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 72   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
# 73   41504   2014-005393-PCO-041504  PERMIT_APPROVED          PCO
# 74   41826   2014-005393-PCO-041826  PERMIT_APPROVED          PCO
#
#    FECHA_SOMETIDO FECHA_EXPEDIDO  \
# 0       12/1/2021      12/6/2021
# 1      10/27/2021     11/17/2021
# 2      10/21/2021      12/6/2021
# 3       10/7/2021     11/23/2021
# ...

# %%
# crear variables de cada palabra
# usar merge para juntarlas todas
# then reset index

# %%
# All construction permits between 2012 and 2021 have been aproved.

df.ESTADO_TRÁMITE.value_counts()
# Out:
# PERMIT_APPROVED    20117
# Name: ESTADO_TRÁMITE, dtype: int64

# %%
df_merge2.to_csv("permisos proyecto 2 - 2012-2021.csv",index=False)

# %% [markdown]
# # Part 3

# %% [markdown]
# Categories were assigned manually to every entry from 2018 to 2021 (years after huracain María) according to the description included in the column "DESCRIPCIÓN_PROYECTO". In between, some entries where not considered since they are not actually developments nor renovations of importance. The year was also assigned date (FECHA) and year (AÑO).

# %%
df_part3 = pd.read_csv("permisos proyecto 2 - 2012-2021.csv", encoding = 'latin1')
df_part3
# Out:
#     CPT_ID                  TRAMITE   ESTADO_TRAMITE TIPO_TRAMITE  \
# 0   838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 1   820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 2   805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 3   822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 4   754935  2018-248619-PCOC-015505  PERMIT_APPROVED         PCOC
# ..     ...                      ...              ...          ...
# 70   41504   2014-005393-PCO-041504  PERMIT_APPROVED          PCO
# 71   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 72   80967   2014-005393-PCO-080967  PERMIT_APPROVED          PCO
# 73   41826   2014-005393-PCO-041826  PERMIT_APPROVED          PCO
# 74   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
#
#    FECHA_SOMETIDO FECHA_EXPEDIDO   FECHA     AÑO  \
# 0       12/1/2021      12/6/2021  21-Dec  2021.0
# 1      10/21/2021      12/6/2021  21-Dec  2021.0
# ...

# %%
df_part3.head(40)
# Out:
#     CPT_ID                  TRAMITE   ESTADO_TRAMITE TIPO_TRAMITE  \
# 0   838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 1   820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 2   805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 3   822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 4   754935  2018-248619-PCOC-015505  PERMIT_APPROVED         PCOC
# 5   774278  2020-298040-PCOC-016789  PERMIT_APPROVED         PCOC
# 6   739894  2021-364489-PCOC-014377  PERMIT_APPROVED         PCOC
# 7   701715  2021-352689-PCOC-011978  PERMIT_APPROVED         PCOC
# 8   752237  2021-364378-PCOC-015301  PERMIT_APPROVED         PCOC
# 9   741719  2020-298040-PCOC-014502  PERMIT_APPROVED         PCOC
# 10  725670  2021-364378-PCOC-013407  PERMIT_APPROVED         PCOC
# 11  707843  2019-289961-PCOC-012341  PERMIT_APPROVED         PCOC
# 12  698885  2021-351364-PCOC-011815  PERMIT_APPROVED         PCOC
# ...

# %%
df_part3.dtypes
# Out:
# CPT_ID                    int64
# TRAMITE                  object
# ESTADO_TRAMITE           object
# TIPO_TRAMITE             object
# FECHA_SOMETIDO           object
# FECHA_EXPEDIDO           object
# FECHA                    object
# AÑO                     float64
# NOMBRE_PROYECTO          object
# DESCRIPCION_PROYECTO     object
# CATEGORIA                object
# CODE_CATEGORIA           object
# SOLICITANTE              object
# MUNICIPIO                object
# CDBG_DR                   int64
# COORDENADAS_LAT         float64
# COORDENADAS_LON         float64
# dtype: object

# %%
df_part3.AÑO = df_part3.AÑO.astype('string')
df_part3.AÑO
# Out:
# 0     2021.0
# 1     2021.0
# 2     2021.0
# 3     2021.0
# 4     2021.0
#        ...
# 70      <NA>
# 71      <NA>
# 72      <NA>
# 73      <NA>
# 74      <NA>
# Name: AÑO, Length: 75, dtype: string

# %%
df_part3
# Out:
#     CPT_ID                  TRAMITE   ESTADO_TRAMITE TIPO_TRAMITE  \
# 0   838010  2020-298040-PCOC-020820  PERMIT_APPROVED         PCOC
# 1   820083  2018-248043-PCOC-019759  PERMIT_APPROVED         PCOC
# 2   805077  2021-400214-PCOC-018803  PERMIT_APPROVED         PCOC
# 3   822963  2021-387502-PCOC-019943  PERMIT_APPROVED         PCOC
# 4   754935  2018-248619-PCOC-015505  PERMIT_APPROVED         PCOC
# ..     ...                      ...              ...          ...
# 70   41504   2014-005393-PCO-041504  PERMIT_APPROVED          PCO
# 71   90644   2015-063621-PCO-090644  PERMIT_APPROVED          PCO
# 72   80967   2014-005393-PCO-080967  PERMIT_APPROVED          PCO
# 73   41826   2014-005393-PCO-041826  PERMIT_APPROVED          PCO
# 74   54797   2015-041888-PCO-054797  PERMIT_APPROVED          PCO
#
#    FECHA_SOMETIDO FECHA_EXPEDIDO   FECHA     AÑO  \
# 0       12/1/2021      12/6/2021  21-Dec  2021.0
# 1      10/21/2021      12/6/2021  21-Dec  2021.0
# ...

# %%
df_part3.CATEGORIA.value_counts()
# Out:
# Development              25
# Expansion/ Renovating    25
# Utilities                 2
# Name: CATEGORIA, dtype: int64

# %% [markdown]
# A code letter was assigned to map the sites on a map based on the impact to show points with different sizes:
#
#     A = Development
#     B = Expansion/ Renovating + Utilities

# %%
df_part3["CODE_CATEGORIA"].value_counts()
# Out:
# B    27
# A    25
# Name: CODE_CATEGORIA, dtype: int64

# %%
df_part3.groupby("AÑO").CODE_CATEGORIA.value_counts().to_frame()
# Out:
#                        CODE_CATEGORIA
# AÑO    CODE_CATEGORIA
# 2018.0 B                            5
#        A                            1
# 2019.0 B                           11
#        A                            5
# 2020.0 A                           10
#        B                            3
# 2021.0 A                            9
#        B                            8

# %% [markdown]
# filtrar para solo ver CODE_CATEGORIA == A y quienes son los desarrolladores usando SOLICITANTE y NOMBRE_PROYECTO

# %%
CODE_A = df_part3[df_part3.CODE_CATEGORIA == 'A']

# %%
CODE_A.NOMBRE_PROYECTO.value_counts().to_frame()
# Out:
#                                                     NOMBRE_PROYECTO
# JW Marriott Hotel & Marriott Vacation Club Inte...                6
# Atlantic Estates at Bahia Beach Resort                            2
# Beachfront Residences at Dorado Beach Resort V                    2
# Residence Inn by Marriott                                         2
# West Point Residences & Residents' Beach Club                     1
# DBR West Point Residences I                                       1
# TrÃpica Beach Hotel Annex                                        1
# JRC International Boutique Hotel & Business Cen...                1
# HOTEL COCO'S                                                      1
# ConstrucciÃn de Planta de Utilidades                             1
# HOTEL DON RAFA                                                    1
# Posada PeÃuelas                                                  1
# Punta Borinquen Resort Aguadilla                                  1
# ...
